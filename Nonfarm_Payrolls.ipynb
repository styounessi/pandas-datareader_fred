# %%
import pandas_datareader as pdr
import plotly.express as px
import pandas as pd
import datetime
from datetime import date

# %%
start = datetime.datetime(2005, 1, 1)
end = date.today()

df = pdr.DataReader('PAYEMS', 'fred', start, end)

display(df)
# Out:
#             PAYEMS
# DATE
# 2005-01-01  132774
# 2005-02-01  133032
# 2005-03-01  133156
# 2005-04-01  133518
# 2005-05-01  133690
# ...            ...
# 2020-07-01  139570
# 2020-08-01  141063
# 2020-09-01  141774
# 2020-10-01  142384
# 2020-11-01  142629
#
# [191 rows x 1 columns]

# %%
df = df*1000

display(df)
# Out:
#                PAYEMS
# DATE
# 2005-01-01  132774000
# 2005-02-01  133032000
# 2005-03-01  133156000
# 2005-04-01  133518000
# 2005-05-01  133690000
# ...               ...
# 2020-07-01  139570000
# 2020-08-01  141063000
# 2020-09-01  141774000
# 2020-10-01  142384000
# 2020-11-01  142629000
#
# [191 rows x 1 columns]

# %%
fig = px.line(df, y='PAYEMS',
              title='Total Nonfarm Payrolls, 2005 to Present',
              labels={'PAYEMS':'All Nonfarm Employees'})

fig.show(renderer='png')

# %%
df = df['PAYEMS'].diff()

display(df)
# Out:
# DATE
# 2005-01-01          NaN
# 2005-02-01     258000.0
# 2005-03-01     124000.0
# 2005-04-01     362000.0
# 2005-05-01     172000.0
#                 ...
# 2020-07-01    1761000.0
# 2020-08-01    1493000.0
# 2020-09-01     711000.0
# 2020-10-01     610000.0
# 2020-11-01     245000.0
# Name: PAYEMS, Length: 191, dtype: float64

# %%
fig = px.bar(df, y='PAYEMS',
             title='Monthly Change in Nonfarm Payrolls, 2005 to Present',
             labels={'PAYEMS':'Monthly Payroll Change'})

fig.show(renderer='png')
