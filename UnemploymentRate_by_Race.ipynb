# %%
import pandas_datareader as pdr
import pandas as pd
import plotly.express as px
import datetime
from datetime import date

# %%
start = datetime.datetime(2000, 1, 1)
end = date.today()

df = pdr.DataReader(['LNS14000003', 'LNS14000006', 'LNS14000009','LNU04032183'],
                    'fred', start, end)

df = df.rename(columns={'LNS14000003':'White',
                        'LNS14000006':'Black',
                        'LNS14000009':'Hispanic or Latino',
                        'LNU04032183':'Asian'})
display(df)
# Out:
#             White  Black  Hispanic or Latino  Asian
# DATE
# 2000-01-01    3.4    8.2                 5.6    4.0
# 2000-02-01    3.6    8.1                 5.7    3.4
# 2000-03-01    3.5    7.4                 6.1    4.1
# 2000-04-01    3.4    7.0                 5.5    3.1
# 2000-05-01    3.5    7.7                 5.8    3.5
# ...           ...    ...                 ...    ...
# 2020-07-01    9.2   14.6                12.9   12.2
# 2020-08-01    7.3   13.0                10.5   10.7
# 2020-09-01    7.0   12.1                10.3    8.8
# 2020-10-01    6.0   10.8                 8.8    7.5
# 2020-11-01    5.9   10.3                 8.4    6.7
#
# [251 rows x 4 columns]

# %%
fig = px.line(df, y=['White',
                     'Black',
                     'Hispanic or Latino',
                     'Asian'],
              title='Unemployment Rate by Race, 2000 to Present',
              labels={'value':'Percent',
                      'variable':'Race'})

fig.show(renderer='png')

# %%
df2 = df.tail(6)

display(df2)
# Out:
#             White  Black  Hispanic or Latino  Asian
# DATE
# 2020-06-01   10.1   15.4                14.5   13.9
# 2020-07-01    9.2   14.6                12.9   12.2
# 2020-08-01    7.3   13.0                10.5   10.7
# 2020-09-01    7.0   12.1                10.3    8.8
# 2020-10-01    6.0   10.8                 8.8    7.5
# 2020-11-01    5.9   10.3                 8.4    6.7

# %%
fig = px.bar(df2, y=['White',
                     'Black',
                     'Hispanic or Latino',
                     'Asian'],
             barmode='group',
             title='Recent Unemployment Rate by Race',
             text='value',
             labels={'value':'Percent',
                      'variable':'Race'})

fig.update_layout(xaxis_tickangle=-45)
fig.show(renderer='png', width=1300, height=500)
