# %%
import pandas_datareader as pdr
import pandas as pd
import plotly.express as px
import datetime
from datetime import date

# %%
start = datetime.datetime(2019, 6, 1)
end = date.today()

df = pdr.DataReader(['ICSA', 'IC4WSA'],
                    'fred', start, end)

df = df.rename(columns={'ICSA':'Initial Jobless Claims',
                        'IC4WSA':'4 Week Moving Average'})

display(df)
# Out:
#             Initial Jobless Claims  4 Week Moving Average
# DATE
# 2019-06-01                  220000                 217000
# 2019-06-08                  220000                 217750
# 2019-06-15                  219000                 219250
# 2019-06-22                  224000                 220750
# 2019-06-29                  222000                 221250
# ...                            ...                    ...
# 2020-11-14                  748000                 743500
# 2020-11-21                  787000                 750750
# 2020-11-28                  716000                 740500
# 2020-12-05                  862000                 778250
# 2020-12-12                  885000                 812500
#
# [81 rows x 2 columns]

# %%
fig = px.line(df, y=['Initial Jobless Claims',
                     '4 Week Moving Average'],
              title='Initial Jobless Claims, 2018 to Present',
              labels={'value':'Total',
                      'variable':'Claims'})

fig.show(renderer="png")
